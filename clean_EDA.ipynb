# %% [markdown]
# ## Project Work Flow - Defining Business Problem -> Explore Database Tables, Merge and Clean (SQL) -> EDA using Python -> Dashboard Using Tableau -> Report Writing

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, text
import urllib.parse

# Credentials and connection
user = "amrituser"
password = urllib.parse.quote("Amrit@2004")
host = "127.0.0.1"
port = "3306"

# Create engine (no DB yet)
engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}")

# Connect and create DB
conn = engine.connect()
conn.execute(text("CREATE DATABASE IF NOT EXISTS csv_ingestion_db"))
print("✅ Database created or already exists.")
conn.close()
# Out:
# ✅ Database created or already exists.

# %%
# After DB has been created
database = "csv_ingestion_db"

engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}")

# %%
import pandas as pd
import numpy as np 
import os

# %%
import pandas as pd
import numpy as np 
import os

for file in os.listdir('/Users/abcd/Desktop/cooding/notebook/Vendor Performance Analysis/data'):
    if file.endswith('.csv'):
        file_path = os.path.join('/Users/abcd/Desktop/cooding/notebook/Vendor Performance Analysis/data', file)
        table_name = os.path.splitext(file)[0]

        print(f"Uploading: {file} → Table: {table_name}")

# Push to MySQL table
        chunk_size = 400000
        i = 0;
        for chunk in pd.read_csv(file_path, chunksize=chunk_size):
            chunk.to_sql(table_name, con=engine, index=False, if_exists='append')
            print(f"chunk uploaded : {i}")
            i += 1


print("All files uploaded successfully.")
# Out:
# Uploading: purchases.csv → Table: purchases
# chunk uploaded : 0
# chunk uploaded : 1
# chunk uploaded : 2
# chunk uploaded : 3
# chunk uploaded : 4
# chunk uploaded : 5
# Uploading: purchase_prices.csv → Table: purchase_prices
# chunk uploaded : 0
# Uploading: vendor_invoice.csv → Table: vendor_invoice
# chunk uploaded : 0
# Uploading: begin_inventory.csv → Table: begin_inventory
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[4], line 16
#      14 i = 0;
#      15 for chunk in pd.read_csv(file_path, chunksize=chunk_size):
# ---> 16     chunk.to_sql(table_name, con=engine, index=False, if_exists='append')
#      17     print(f"chunk uploaded : {i}")
#      18     i += 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %% [markdown]
# ### Exploration od Data
# #### Understanding how the data is present in the database and if there is need creating some aggregated tables that may help with vendor selection with profitability and Product pricing optimization

# %%
from sqlalchemy import inspect

inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['begin_inventory', 'end_inventory', 'purchase_prices', 'purchases', 'sales', 'vendor_invoice']

# %%
tables = ['purchases', 'purchase_prices', 'sales', 'vendor_invoice', 'begin_inventory', 'end_inventory']

for table in tables:
    count = pd.read_sql_query(f"SELECT COUNT(*) AS total FROM {table}", con=engine)['total'].iloc[0]
    sample = pd.read_sql_query(f"SELECT * FROM {table} LIMIT 1", con=engine)
    col_count = len(sample.columns)
    print(f"Count of records in {table} table: {count},{col_count}")
    display(pd.read_sql_query(f"SELECT * FROM {table} limit 5", con = engine))
# Out:
# Count of records in purchases table: 7917422,16
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
# ...

# %%
purchases = pd.read_sql_query("SELECT * FROM purchases WHERE VendorNumber = 4466", con=engine)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 7260     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 7261   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 7262    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 7263     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 7264    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices WHERE VendorNumber = 4466", con=engine)
purchase_prices
# Out:
#     Brand                   Description  Price    Size Volume  Classification  \
# 0    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 3    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 4    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 5    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 6    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 7    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 8    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 9    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 10   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# ...

# %%
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice WHERE VendorNumber = 4466", con=engine)
vendor_invoice
# Out:
#      VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0            4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1            4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2            4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3            4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4            4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# ..            ...                          ...         ...       ...
# 215          4466  AMERICAN VINTAGE BEVERAGE    2024-12-06     13134
# 216          4466  AMERICAN VINTAGE BEVERAGE    2024-12-16     13254
# 217          4466  AMERICAN VINTAGE BEVERAGE    2024-12-26     13432
# 218          4466  AMERICAN VINTAGE BEVERAGE    2024-12-30     13483
# 219          4466  AMERICAN VINTAGE BEVERAGE    2025-01-09     13627
#
#          PODate     PayDate  Quantity  Dollars  Freight Approval
# 0    2023-12-22  2024-02-21        15   140.55     8.57     None
# ...

# %%
sales = pd.read_sql_query("SELECT * FROM sales WHERE VendorNo = 4466", con=engine)
sales
# Out:
#                InventoryId  Store  Brand                   Description   Size  \
# 0      1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1      1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2      1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3      1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4      1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                    ...    ...    ...                           ...    ...
# 18901     9_BLACKPOOL_5215      9   5215  TGI Fridays Long Island Iced  1.75L
# 18902     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 18903     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 18904     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 18905     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases.groupby(['Brand', 'PurchasePrice'])[['Quantity', 'Dollars']].sum()
# Out:
#                      Quantity    Dollars
# Brand PurchasePrice
# 3140  11.19             14775  165332.25
# 5215  9.41              16529  155537.89
# 5255  9.35              20587  192488.45

# %%
purchase_prices
# Out:
#     Brand                   Description  Price    Size Volume  Classification  \
# 0    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 3    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 4    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 5    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 6    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 7    5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 8    3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
# 9    5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 10   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# ...

# %%
vendor_invoice['PONumber'].nunique()
# Out:
# 55

# %%
vendor_invoice.shape
# Out:
# (220, 10)

# %% [markdown]
# #### As we need the data for analysis is distributed in different tables, we need o create a summary table means aggregated table on the basis of primary and foreign keys or ERD
# - purchase table made by vendors
# - sales transaction data
# - freight costs or delivery costs for each vendors - in vendor invoive table
# - actual product prices from vendors

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""
    SELECT VendorNumber, VendorName, SUM(Freight) as FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber, VendorName
""", con=engine)

# %%
freight_summary
# Out:
#      VendorNumber                   VendorName  FreightCost
# 0             105  ALTAMAR BRANDS LLC                249.56
# 1            4466  AMERICAN VINTAGE BEVERAGE        3175.64
# 2             388  ATLANTIC IMPORTING COMPANY        846.96
# 3             480  BACARDI USA INC                357145.08
# 4             516  BANFI PRODUCTS CORP             34041.64
# ..            ...                          ...          ...
# 124          4901  LAUREATE IMPORTS CO                 2.88
# 125         90059  BLACK COVE BEVERAGES              299.36
# 126          5083  LOYAL DOG WINERY                   42.72
# 127          1587  VINEYARD BRANDS LLC               216.92
# 128            54  AAPER ALCOHOL & CHEMICAL CO         1.92
#
# [129 rows x 3 columns]

# %% [markdown]
# - now we'll join the purchases table and purchase_prices table

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""
    SELECT
        p.VendorName,
        p.VendorNumber,
        p.Brand,
        p.PurchasePrice,
        
        pp.Volume,
        pp.Price AS `Actual Price`,

        SUM(p.Quantity) AS Total_Purchase_Quantity,
        SUM(p.Dollars) AS Total_Purchase_Dollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
        WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.PurchasePrice, pp.Volume, pp.Price
    ORDER BY Total_Purchase_Dollars
""", con=engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 19
#       1 pd.read_sql_query("""
#       2     SELECT
#       3         p.VendorName,
#       4         p.VendorNumber,
#       5         p.Brand,
#       6         p.PurchasePrice,
#       7
#       8         pp.Volume,
#       9         pp.Price AS `Actual Price`,
#      10
#      11         SUM(p.Quantity) AS Total_Purchase_Quantity,
#      12         SUM(p.Dollars) AS Total_Purchase_Dollars
#      13     FROM purchases p
#      14     JOIN purchase_prices pp
#      15         ON p.Brand = pp.Brand
#      16         WHERE p.PurchasePrice > 0
#      17     GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.PurchasePrice, pp.Volume, pp.Price
#      18     ORDER BY Total_Purchase_Dollars
# ---> 19 """, con=engine)
#
# NameError: name 'engine' is not defined

# %% [markdown]
# - now utilizing required data from sales table

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd
